# %%
# Conectando o Colab com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Verificando os arquivos.
# !ls '/content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training/custom_data'
# Out:
# 0.jpg	17.txt	25.jpg	33.txt	42.jpg	50.jpg
# 0.txt	18.jpg	25.txt	34.jpg	42.txt	50.txt
# 10.jpg	18.txt	26.jpg	35.jpg	43.jpg	5.jpg
# 10.txt	19.jpg	27.jpg	36.jpg	43.txt	5.txt
# 11.jpg	19.txt	27.txt	36.txt	44.jpg	6.jpg
# 11.txt	1.jpg	28.jpg	37.jpg	44.txt	7.jpg
# 12.jpg	1.txt	28.txt	37.txt	45.jpg	7.txt
# 12.txt	20.jpg	29.jpg	38.jpg	45.txt	8.jpg
# 13.jpg	20.txt	29.txt	38.txt	46.jpg	9.jpg
# 13.txt	21.jpg	2.jpg	39.jpg	46.txt	9.txt
# 14.jpg	21.txt	2.txt	39.txt	47.jpg	classes.names
# 14.txt	22.jpg	30.jpg	3.jpg	47.txt	classes.txt
# 15.jpg	22.txt	30.txt	3.txt	48.jpg	creating-files-data-and-name.py
# 15.txt	23.jpg	31.jpg	40.jpg	49.jpg	creating-train-and-test-txt-files.py
# 16.jpg	23.txt	31.txt	40.txt	49.txt	labelled_data.data
# 16.txt	24.jpg	32.jpg	41.jpg	4.jpg	test.txt
# 17.jpg	24.txt	33.jpg	41.txt	4.txt	train.txt

# %%
# Clonando o repositório para o Drive
# !git clone 'https://github.com/pjreddie/darknet' '/content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training/darknet'
# Out:
# fatal: destination path '/content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training/darknet' already exists and is not an empty directory.

# %%
# Mudando para o diretório do repositório
# %cd /content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training/darknet
# Out:
# /content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training/darknet

# %%
# Verificando se os arquivos estão todos dentro do repositório
# !ls
# Out:
# backup	 examples	LICENSE       LICENSE.meta  obj        scripts
# cfg	 include	LICENSE.fuck  LICENSE.mit   python     src
# darknet  libdarknet.a	LICENSE.gen   LICENSE.v1    README.md
# data	 libdarknet.so	LICENSE.gpl   Makefile	    results

# %%
# !make
# Out:
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  --compiler-options "-Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc fatal   : Unsupported gpu architecture 'compute_30'
# Makefile:92: recipe for target 'obj/convolutional_kernels.o' failed
# make: *** [obj/convolutional_kernels.o] Error 1

# %%
# %cd /content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training
# Out:
# /content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# %cd '/content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training/darknet'
# Out:
# /content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training/darknet

# %%
# !chmod +x darknet

# %%
# %cd '/content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training'
# Out:
# /content/drive/MyDrive/ - projeto_brasil_6g/yolo_custom_model_training

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# yolov3_custom
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32  0.177 BFLOPs
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     4 res    1                 208 x 208 x  64   ->   208 x 208 x  64
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     8 res    5                 104 x 104 x 128   ->   104 x 104 x 128
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
# ...

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>
