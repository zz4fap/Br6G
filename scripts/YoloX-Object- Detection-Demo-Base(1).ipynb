# %% [markdown]
# # **Run YOLOX on Google Colab - Images & Video**
#
#
# ![image:png](https://github.com/Megvii-BaseDetection/YOLOX/raw/main/assets/logo.png)
#
#
# <p>YoloX just got released, and it is better and faster than, YoloR, YoloV4, Scaled YoloV4, YoloV5 and PP-YOLOv2. In this YOLOR Object Detection Tutorial I am going to show you how to get YOLOX working on Collab, on Images and Video. All right here and right now. No time to waste guys, lets get started!!</p>
#
#
#
# # **Want to Become a YOLOX Expert?**
# 💻Get Started with YOLOX [Get Started](https://www.augmentedstartups.com/yolox-registration). <br>
# ⭐ Download the Code at the [AI Vision Store](https://augmentedstartups.info/VisionStore)<br>
# ☕ Buy me [Chai/Coffee](https://bit.ly/BuymeaCoffeeAS)
#
# # **Tutorial**
# ####Steps
# 1. *Cloning the Repositery*
# 2. *Installing Requirements*
# 3. *Installing and Building YoloX*
# 4. *Connecting the Grdrive*
# 5. *Download Sample Files and Weights*
# 6. *Demo for Image*
# 7. *Demo for Video*
#
# # **About US**
# [Augmented Startups](https://www.augmentedstartups.com) provides tutorials in AI Computer Vision and Augmented Reality. With over **96K subscribers** on our channel, we teach state-of-art models and build apps and projects that solve real-world problems.
#
# ![image:png](https://kajabi-storefronts-production.kajabi-cdn.com/kajabi-storefronts-production/sites/104576/images/Vc8nhFV6Rgmi402Wqm0Q_AugmentedStartupsSideROBOTICSNEW.png)
#
# <br>
#
# #From the Author
# ## Hey there <img src="https://media.giphy.com/media/hvRJCLFzcasrR4ia7z/giphy.gif" width="25px">
#
# **I am Rohit Kukreja - A Computer Vision & Deep Learning Practitioner**
#
#
# <a href="https://github.com/rohitkuk">
#   <img align="left" alt="Rohit Kukreja Github" width="22px" src="https://cdn-icons-png.flaticon.com/512/25/25231.png" />
# </a>
# <a href="https://twitter.com/_Rohitkukreja">
#   <img align="left" alt="Rohit Kukreja | Twitter" width="22px" src="https://raw.githubusercontent.com/peterthehan/peterthehan/master/assets/twitter.svg" />
# </a>
# <a href="https://www.linkedin.com/in/rohitkuk/">
#   <img align="left" alt="Rohit's's LinkedIN" width="22px" src="https://raw.githubusercontent.com/peterthehan/peterthehan/master/assets/linkedin.svg" />
# </a>
# <a href="rohit.kukreja01@gmail.com">
#   <img align="left" alt="Rohit Kukreja Email" width="22px" src="https://logos-world.net/wp-content/uploads/2020/11/Gmail-Logo.png" />
# </a>

# %% [markdown]
# #Basic Setup

# %%
# Mounting Google Drive

# %%
# Cloning the Yolo X Repo

# %% [markdown]
# #Installing dependencies

# %%
# Installing requirementes.txt

# %%
# builing pycocotools

# %%
# Installing and Building Yolox

# %% [markdown]
# #Getting the Files ready

# %%
# Creating the wieghts folder

# %%
# # Download Weights
# !wget -nc https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_s.pth -P /content/YOLOX/weights 
# !wget -nc https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_m.pth -P /content/YOLOX/weights 
# !wget -nc https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_l.pth -P /content/YOLOX/weights 
# !wget -nc https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_x.pth -P /content/YOLOX/weights 
# !wget -nc https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_darknet.pth -P /content/YOLOX/weights 
# !wget -nc https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_nano.pth -P /content/YOLOX/weights 
# !wget -nc https://github.com/Megvii-BaseDetection/YOLOX/releases/download/0.1.1rc0/yolox_tiny.pth -P /content/YOLOX/weights

# %%
# Download Sample Video and Image
"""
  Sample Video :: https://drive.google.com/u/0/uc?id=1PygamUfpcCcCzQsKHu1cwPo4PrlxbNH_&export=download
  Sample Image :: https://drive.google.com/u/0/uc?id=1fKI4aldzz6Y-iAldhncZ6GQlD7Xl3ICV&export=download 
"""

# %% [markdown]
# #Demo

# %% [markdown]
# ```
# CLI Arguments Details
#
#    demo   =  Choose between [image, video, webcam]
#  --name   = [yolox-s, yolox-x,......]
#  --ckpt   = Path to the wieghts file for yolox model
#  --path   = file path
#  --conf   = 0.25
#  --nms    = 0.45
#  --device = [gpu,cpu]
#  --save_result
#
#  Have used backward slashes to unbreak line \
# ```

# %%
# Demo for Image
# !python tools/demo.py image -n yolox-s -c /content/YOLOX/weights/yolox_s.pth --path assets/dog.jpg --conf 0.25 --nms 0.45 --tsize 640 --save_result --device gpu

# %%
# Demo for Video
