# %%
# Conectando o Colab com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Verificando os arquivos.
# !unzip '/content/drive/MyDrive/00brasil6g/arquivos_backup/dataset_utilizado.zip' -d '/content/drive/MyDrive/00brasil6g/yolo_custom_model_Training'
# Out:
# Archive:  /content/drive/MyDrive/00brasil6g/arquivos_backup/dataset_utilizado.zip
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/13.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/9.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/44.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/36.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/39.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/33.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/41.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/0.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/40.txt
#   inflating: /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/dataset/49.txt
# ...

# %%
# %cd '/content/drive/MyDrive/00brasil6g/yolo_custom_model_Training'
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training

# %%
# !git clone 'https://github.com/pjreddie/darknet'
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5943, done.
# remote: Total 5943 (delta 0), reused 0 (delta 0), pack-reused 5943
# Receiving objects: 100% (5943/5943), 6.37 MiB | 5.94 MiB/s, done.
# Resolving deltas: 100% (3926/3926), done.
# Checking out files: 100% (979/979), done.

# %%
# %cd '/content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/darknet'
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/darknet

# %%
# !ls
# Out:
# cfg	  include	LICENSE.gen   LICENSE.mit  python     src
# data	  LICENSE	LICENSE.gpl   LICENSE.v1   README.md
# examples  LICENSE.fuck	LICENSE.meta  Makefile	   scripts

# %%
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# gcc -Iinclude/ -Isrc/ -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -c ./src/list.c -o obj/list.o
# ...

# %%
# %cd /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training

# %%
# !python /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/custom_data/creating-files-data-and-name.py

# %%
# !python /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/custom_data/creating-train-and-test-txt-files.py

# %%
# %cd '/content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/darknet'
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/darknet

# %%
# !chmod +x ./darknet

# %%
# %cd '/content/drive/MyDrive/00brasil6g/yolo_custom_model_Training'
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# yolov3_custom
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32  0.177 BFLOPs
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     4 res    1                 208 x 208 x  64   ->   208 x 208 x  64
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     8 res    5                 104 x 104 x 128   ->   104 x 104 x 128
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
# ...

# %% [markdown]
# Treinando

# %%
# Conectando o Colab com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training

# %%
# !ls
# Out:
# backup	custom_data  custom_weight  darknet

# %%
# %cd /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/darknet
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/darknet

# %%
# !make
# Out:
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  --compiler-options "-Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc fatal   : Unsupported gpu architecture 'compute_30'
# Makefile:92: recipe for target 'obj/convolutional_kernels.o' failed
# make: *** [obj/convolutional_kernels.o] Error 1

# %%
# %cd /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/darknet
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training/darknet

# %%
# !chmod +x ./darknet

# %%
# %cd /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training
# Out:
# /content/drive/MyDrive/00brasil6g/yolo_custom_model_Training

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# yolov3_custom
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32  0.177 BFLOPs
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     4 res    1                 208 x 208 x  64   ->   208 x 208 x  64
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     8 res    5                 104 x 104 x 128   ->   104 x 104 x 128
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
# ...
